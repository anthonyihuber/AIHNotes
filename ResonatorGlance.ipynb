# %%
import skrf as rf
import matplotlib.pyplot as plt
import numpy as np

# %%
CDD = 'C:/Users/antho/OneDrive/Desktop/School/PhD/PrimeCam/Cooldown S2P Data/'

# %%
dataset = '230201_RESONATOR_NOISE_ON_RESONANCE.S2P'

# %%
data = rf.Network(CDD + dataset)

# %%
plt.plot(data.f)

# %%
s21 = data.s[:,1,0]

# %%
fft_data = np.fft.fft(s21)
fft_freq = np.fft.fftfreq(len(s21),d=0.001)
fft_phase = np.angle(fft_data)
print(round(len(fft_freq)/2))
fft_freq[round(len(fft_freq)/2)]
fft_freq[0]
# Out:
# 800
# 0.0

# %%
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_data[0:round(len(fft_freq)/2)])
#  plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))

# %%
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_phase[0:round(len(fft_freq)/2)])
plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))
# Out:
# (0.0, 499.0630855715178)

# %%
np.where(fft_data == max(fft_data))
# Out:
# (array([0], dtype=int64),)

# %%
d2 = np.fft.fft(abs(s21))
fft_freq = np.fft.fftfreq(len(s21),d=0.001)
d2[0] = 0
fft_phase2 = np.angle(fft_data)

# %%
plt.plot(abs(s21))

# %%
plt.plot(fft_freq[0:round(len(fft_freq)/2)],d2[0:round(len(fft_freq)/2)])
#  plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))

# %%
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_phase[0:round(len(fft_freq)/2)])
plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))
# Out:
# (0.0, 499.0630855715178)

# %%
dataset2 = '230201_RESONATOR_NOISE_OFF_RESONANCE.S2P'

# %%
data2 = rf.Network(CDD + dataset2)

# %%
d11 = data.s[:,0,0]
d12 = data.s[:,0,1]
d21 = data.s[:,1,0]
d22 = data.s[:,1,1]


fft_d11 = np.fft.fft(abs(d11))
fft_d12 = np.fft.fft(abs(d12))
fft_d21 = np.fft.fft(abs(d21))
fft_d22 = np.fft.fft(abs(d22))
fft_freq = np.fft.fftfreq(len(s21),d=0.001)

phase11 = np.angle(fft_d11)
phase12 = np.angle(fft_d12)
phase21 = np.angle(fft_d21)
phase22 = np.angle(fft_d22)

fft_d11[0] = 0
fft_d12[0] = 0
fft_d21[0] = 0
fft_d22[0] = 0

plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_d11[0:round(len(fft_freq)/2)],label='S11')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_d12[0:round(len(fft_freq)/2)],label='S12')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_d21[0:round(len(fft_freq)/2)],label='S21')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],fft_d22[0:round(len(fft_freq)/2)],label='S22')
plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))

plt.legend()

# %%
# %matplotlib notebook
plt.semilogy(fft_freq[0:round(len(fft_freq)/2)],abs(fft_d11[0:round(len(fft_freq)/2)]),label='S11')
plt.semilogy(fft_freq[0:round(len(fft_freq)/2)],abs(fft_d12[0:round(len(fft_freq)/2)]),label='S12')
plt.semilogy(fft_freq[0:round(len(fft_freq)/2)],abs(fft_d21[0:round(len(fft_freq)/2)]),label='S21')
plt.semilogy(fft_freq[0:round(len(fft_freq)/2)],abs(fft_d22[0:round(len(fft_freq)/2)]),label='S22')
plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))



plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
(fft_freq[1]-fft_freq[0])/(1/1601)
# Out:
# 1000.0

# %%
plt.plot(fft_freq[0:round(len(fft_freq)/2)],phase11[0:round(len(fft_freq)/2)],label='S11')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],phase12[0:round(len(fft_freq)/2)],label='S12')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],phase21[0:round(len(fft_freq)/2)],label='S21')
plt.plot(fft_freq[0:round(len(fft_freq)/2)],phase22[0:round(len(fft_freq)/2)],label='S22')
plt.xlim(min(fft_freq[0:round(len(fft_freq)/2)]),max(fft_freq[0:round(len(fft_freq)/2)]))

plt.legend()

# %%
s11 = data2.s[:,0,0]
s12 = data2.s[:,0,1]
s21 = data2.s[:,1,0]
s22 = data2.s[:,1,1]
sample_rate = 1000

fft_s11 = np.fft.fft(abs(s11))
fft_s12 = np.fft.fft(abs(s12))
fft_s21 = np.fft.fft(abs(s21))
fft_s22 = np.fft.fft(abs(s22))
fft_freq2 = np.fft.fftfreq(len(s21),d=1/sample_rate)

phases11 = np.angle(fft_s11)
phases12 = np.angle(fft_s12)
phases21 = np.angle(fft_s21)
phases22 = np.angle(fft_s22)

fft_s11[0] = 0
fft_s12[0] = 0
fft_s21[0] = 0
fft_s22[0] = 0

plt.plot(fft_freq2[0:round(len(fft_freq)/2)],fft_s11[0:round(len(fft_freq)/2)],label='S11')
plt.plot(fft_freq2[0:round(len(fft_freq)/2)],fft_s12[0:round(len(fft_freq)/2)],label='S12')
plt.plot(fft_freq2[0:round(len(fft_freq)/2)],fft_s21[0:round(len(fft_freq)/2)],label='S21')
plt.plot(fft_freq2[0:round(len(fft_freq)/2)],fft_s22[0:round(len(fft_freq)/2)],label='S22')
plt.xlim(min(fft_freq2[0:round(len(fft_freq2)/2)]),max(fft_freq2[0:round(len(fft_freq2)/2)]))

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.semilogy(fft_freq2[0:round(len(fft_freq2)/2)],abs(fft_s11[0:round(len(fft_freq2)/2)]),label='S11')
plt.semilogy(fft_freq2[0:round(len(fft_freq2)/2)],abs(fft_s12[0:round(len(fft_freq2)/2)]),label='S12')
plt.semilogy(fft_freq2[0:round(len(fft_freq2)/2)],abs(fft_s21[0:round(len(fft_freq2)/2)]),label='S21')
plt.semilogy(fft_freq2[0:round(len(fft_freq2)/2)],abs(fft_s22[0:round(len(fft_freq2)/2)]),label='S22')
plt.xlim(min(fft_freq2[0:round(len(fft_freq2)/2)]),max(fft_freq2[0:round(len(fft_freq2)/2)]))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s21
# Out:
# array([0.06088442+0.00897433j, 0.06286872+0.00798084j,
#        0.05993413+0.00844976j, ..., 0.05904334+0.00804405j,
#        0.05960277+0.00947204j, 0.06103878+0.00800844j])

# %%
time = np.arange(0,(len(s21))/sample_rate, 1/sample_rate)
plt.plot(time,s21)
# Out:
# <img src="data:image/png;base64,..." width="640">
